# %%
reset

# %%
# modulos
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.patches import Rectangle
# from tkinter import *
# from tkinter import ttk
plt.style.use('classic')
from matplotlib.animation import FuncAnimation

# %%
# estilo de graficos
plt.style.use('classic')

# Crear una figura y un objeto de ejes
fig, ax = plt.subplots()

# Definir dimensiones del espacio de trabajo

fig.set_size_inches(10.5, 10.5)

# Crear un cuadrado generador en el centro del objeto GENERADOR
suma_lista = []
center = [0, 0]
dimensions = [0.3, 0.3]
dime = [elemento/2 for elemento in dimensions]

# Suma de vectores

for elemento1, elemento2 in zip(center, dime):
    suma = elemento1 - elemento2
    suma_lista.append(suma)

# Crear un cuadrado generador en el centro del objeto FONDO VERTICAL

suma_lista2 = []
center2 = [0, 0]
dimensions2 = [0.6, 1]
dime2 = [elemento2/2 for elemento2 in dimensions2]

# Suma de vectores

for elemento1, elemento2 in zip(center2, dime2):
    suma2 = elemento1 - elemento2
    suma_lista2.append(suma2)

# Crear un cuadrado generador en el centro del objeto FONDO HORIZONTAL

suma_lista3 = []
center3 = [0, 0]
dimensions3 = [1, 0.6]
dime3 = [elemento3/2 for elemento3 in dimensions3]

# Suma de vectores

for elemento1, elemento2 in zip(center3, dime3):
    suma3 = elemento1 - elemento2
    suma_lista3.append(suma3)

font1 = patches.Rectangle(suma_lista2, dimensions2[0], dimensions2[1], linewidth=2, edgecolor='black', facecolor='black')
font2 = patches.Rectangle(suma_lista3, dimensions3[0], dimensions3[1], linewidth=2, edgecolor='black', facecolor='black')
generator = patches.Rectangle(suma_lista, dimensions[0], dimensions[1], linewidth=2, edgecolor='r', facecolor='red')

# Agregar el cuadrado al objeto de ejes
ax.add_patch(font1)
ax.add_patch(font2)
ax.add_patch(generator)

# Agregar grilla

ax.grid()

# titulo

ax.set_title(r'$\beta$')
ax.set_ylabel('y (m)')
ax.set_xlabel('x (m)')

# Establecer los límites de los ejes

L = 0.5
step = 10**-1
num = int(1/step)

ax.set_xlim(-L, L)
ax.set_ylim(-L, L)
plt.xticks(np.linspace(-L,L,8))
plt.yticks(np.linspace(-L,L,8))

# Mostrar el gráfico
plt.show()

# %%
# estilo de graficos
plt.style.use('classic')

# Crear una figura y un objeto de ejes
fig, ax = plt.subplots()

# Definir dimensiones del espacio de trabajo

fig.set_size_inches(10.5, 10.5)

# Crear un cuadrado generador en el centro del objeto GENERADOR

suma_lista = []
center = [0, 0]
dimensions = [0.3, 0.3]

dime = [elemento/2 for elemento in dimensions]

# Suma de vectores

for elemento1, elemento2 in zip(center, dime):
    suma = elemento1 - elemento2
    suma_lista.append(suma)

# Crear un cuadrado generador en el centro del objeto FONDO VERTICAL

suma_lista2 = []
center2 = [0, 0]
dimensions2 = [0.6, 1]
dime2 = [elemento2/2 for elemento2 in dimensions2]

# Suma de vectores

for elemento1, elemento2 in zip(center2, dime2):
    suma2 = elemento1 - elemento2
    suma_lista2.append(suma2)

# Crear un cuadrado generador en el centro del objeto FONDO HORIZONTAL

suma_lista3 = []
center3 = [0, 0]
dimensions3 = [1, 0.6]
dime3 = [elemento3/2 for elemento3 in dimensions3]

# Suma de vectores

for elemento1, elemento2 in zip(center3, dime3):
    suma3 = elemento1 - elemento2
    suma_lista3.append(suma3)

font1 = patches.Rectangle(suma_lista2, dimensions2[0], dimensions2[1], linewidth=2, edgecolor='black', facecolor='black')
font2 = patches.Rectangle(suma_lista3, dimensions3[0], dimensions3[1], linewidth=2, edgecolor='black', facecolor='black')
generator = patches.Rectangle(suma_lista, dimensions[0], dimensions[1], linewidth=2, edgecolor='r', facecolor='red')

# Agregar el cuadrado al objeto de ejes
ax.add_patch(font1)
ax.add_patch(font2)
ax.add_patch(generator)

# agregar malla
# Crear una cuadrícula de puntos

x = np.linspace(0,0.6,61)  # Coordenadas x de los puntos
y = np.linspace(0,0.6,61)  # Coordenadas y de los puntos

# Crear una cuadrícula de puntos vacios
x2 = np.linspace(0.31, 0.6, 30)  # Coordenadas x de los puntos
y2 = np.linspace(0.31, 0.6, 30)  # Coordenadas y de los puntos

# Crear una malla de coordenadas utilizando la función meshgrid
X, Y = np.meshgrid(x, y)
# Crear una malla de coordenadas utilizando la función meshgrid
X2, Y2 = np.meshgrid(x2, y2)

# Eliminar los puntos de las matrices X e Y
indices_a_eliminarx = np.linspace(31,60,30)
indices_a_eliminary = np.linspace(31,60,30)

for indice_x in indices_a_eliminarx:
    for indice_y in indices_a_eliminary:
        X[int(indice_x), int(indice_y)] = np.nan
        Y[int(indice_x), int(indice_y)] = np.nan

# Trazar la malla de puntos utilizando scatter
ax.scatter(X, Y, color='blue', marker='.', s=50)
# ax.scatter(X2, Y2, color='white', marker='.', s=50)
line = np.linspace(0,0.5,100)
# ax.plot(line,line, color="yellow")
# Agregar grilla

ax.grid()

# titulo

ax.set_title(r'$\alpha$')
ax.set_ylabel('y (m)')
ax.set_xlabel('x (m)')

# Establecer los límites de los ejes

L = 0.5
step = 10**-1
num = int(1/step)

ax.set_xlim(0, L)
ax.set_ylim(0, L)
# plt.xticks(np.linspace(-L,L,8))
# plt.yticks(np.linspace(-L,L,8))
plt.savefig('erasmus.png')
# Mostrar el gráfico
plt.show()

# %%
# Crear una cuadrícula de puntos
x = np.linspace(0,0.5,51)  # Coordenadas x de los puntos
y = np.linspace(0,0.5,51)  # Coordenadas y de los puntos

# Crear una malla de coordenadas utilizando la función meshgrid
X, Y = np.meshgrid(x, y)

# Crear una figura y un objeto de ejes
fig, ax = plt.subplots()

# Trazar la malla de puntos utilizando scatter
ax.scatter(X, Y, c='blue', marker='.')

# Configurar etiquetas de los ejes
ax.set_xlabel('Coordenada X')
ax.set_ylabel('Coordenada Y')

# Título del gráfico
ax.set_title('Malla usada')

# Mostrar el gráfico
plt.grid(True)  # Mostrar las líneas de la cuadrícula
fig.savefig('Malla_usada.png')
plt.show()

# %%
# Parámetros del problema
# Define tus parámetros aquí
T_inf = 20 # °C 
delta_x = 1/100 # m
k = 0.08 # w/m2°C
h = 100 # w/m2°C
# Crear una matriz A de tamaño (Nx * Ny, Nx * Ny) llena de ceros
Nx = 51  # Número de nodos en el eje x
Ny = 51  # Número de nodos en el eje y
x_len = 51
y_len = 51
p = 0.5 # m profundidad
A = np.zeros(( x_len*y_len , x_len*y_len))
c = np.zeros(x_len*y_len)

# Define las ecuaciones para nodos interiores, nodos en el borde y nodos en el exterior

# puntos interiores sin generación

def equation_interior(i, j, q):
    # Ecuación para nodos interiores
    idx = i + j * Nx
    A[idx, idx] = -4  # Coeficiente para el nodo actual
    A[idx, idx - 1] = 1  # Coeficiente para el nodo a la izquierda
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx - Nx] = 1  # Coeficiente para el nodo abajo
    c[idx] = 0

# puntos interiores con generación 

def equation_interior_gen(i, j, q):
    # Ecuación para nodos interiores
    idx = i + j * Nx
    A[idx, idx] = -4  # Coeficiente para el nodo actual
    A[idx, idx - 1] = 1  # Coeficiente para el nodo a la izquierda
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx - Nx] = 1  # Coeficiente para el nodo abajo
    c[idx] = (-q*delta_x**2)/(k*p)


# Esquina central

def equation_interior_wc(i, j, q):
    # Ecuación para nodos interiores
    idx = i + j * Nx
    A[idx, idx] = -2*(3 + h*delta_x/k)  # Coeficiente para el nodo actual
    A[idx, idx - 1] = 2  # Coeficiente para el nodo a la izquierda
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx - Nx] = 2  # Coeficiente para el nodo abajo
    c[idx] = -2*h*(delta_x/(k*p))*T_inf


# a la derecha zona convectiva

def equation_plane_wc_der(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -2*(2 + h*delta_x/k)  # Coeficiente para el nodo actual
    A[idx, idx - 1] = 2  # Coeficiente para el nodo a la izquierda
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx - Nx] = 1  # Coeficiente para el nodo abajo
    c[idx] = -2*h*(delta_x/(k*p))*T_inf


# arriba la zona convectiva

def equation_plane_wc_arr(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -2*(2 + h*delta_x/k)  # Coeficiente para el nodo actual
    A[idx, idx - 1] = 1  # Coeficiente para el nodo a la izquierda
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    A[idx, idx - Nx] = 2  # Coeficiente para el nodo abajo
    c[idx] = -2*h*(delta_x/(k*p))*T_inf

# zonas con bordes aislados abajo sin generación

def equation_plane_wc_aba(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -4 # Coeficiente para el nodo actual
    A[idx, idx - 1] = 1  # Coeficiente para el nodo a la izquierda
    A[idx, idx + Nx] = 2  # Coeficiente para el nodo arriba
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    c[idx] = 0

# esquinas zonas convectivas convectivas

def equation_esquina_wc_case4(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -2*((h*delta_x/k) + 1) # Coeficiente para el nodo actual
    A[idx, idx - 1] = 1  # Coeficiente para el nodo a la izquierda
    A[idx, idx - Nx] = 1  # Coeficiente para el nodo abajo
    c[idx] = -2*(h*delta_x/(k*p))*T_inf


# zonas con bordes aislados izquierda sin generación

def equation_plane_wc_izq(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -4  # Coeficiente para el nodo actual
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx + 1] = 2  # Coeficiente para el nodo a la derecha
    A[idx, idx - Nx] = 1  # Coeficiente para el nodo abajo
    c[idx] = 0

# esquinas sin generación y aisladas REVISAR **********************

def equation_esquina_arr(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    # print(idx)
    A[idx, idx] = -(2 + h*delta_x/k)  # Coeficiente para el nodo actual
    A[idx, idx - Nx] = 1  # Coeficiente para el nodo abajo
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    c[idx] = -h*(T_inf*delta_x/(k*p))

def equation_esquina_aba(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -(2 + h*delta_x/k)  # Coeficiente para el nodo actual
    A[idx, idx - 1] = 1  # Coeficiente para el nodo a la izquierda
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    c[idx] = -h*(T_inf-delta_x/(k*p))

# bordes con generación asilados 

def equation_borde_aba(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -4 # Coeficiente para el nodo actual
    A[idx, idx - 1] = 1  # Coeficiente para el nodo a la izquierda
    A[idx, idx + Nx] = 2  # Coeficiente para el nodo arriba
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    c[idx] = -q*(delta_x**2)/(k*p)

def equation_borde_izq(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -4 # Coeficiente para el nodo actual
    A[idx, idx - Nx] = 1  # Coeficiente para el nodo abajo
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx + 1] = 2  # Coeficiente para el nodo a la derecha
    c[idx] = -q*(delta_x**2)/(k*p)

# esquina inferior con generación

def equation_esquina_gen(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -2 # Coeficiente para el nodo actual
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    c[idx] = -q*(delta_x**2)/(2*(k*p))

# esquina inferior con generación y aislada

def equation_esquina_gen_ais_izq(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -3 # Coeficiente para el nodo actual
    A[idx, idx - Nx] = 1  # Coeficiente para el nodo abajo
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    c[idx] = -q*(delta_x**2)/(2*(k*p))

def equation_esquina_gen_ais_aba(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -3 # Coeficiente para el nodo actual
    A[idx, idx - 1] = 1  # Coeficiente para el nodo a la izquierda
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    c[idx] = -q*(delta_x**2)/(2*(k*p))

# esquina interior gen

def equation_esquina_interior_gen(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -4 # Coeficiente para el nodo actual
    A[idx, idx - Nx] = 1  # Coeficiente para el nodo abajo
    A[idx, idx - 1] = 1  # Coeficiente para el nodo a la izquierda
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    c[idx] = -q*(delta_x**2)/(4*(k*p))

# bordes con generación no aislados REVISAR *****************

def equation_borde_gen(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -4 # Coeficiente para el nodo actual
    A[idx, idx - Nx] = 1  # Coeficiente para el nodo abajo
    A[idx, idx - 1] = 1  # Coeficiente para el nodo a la izquierda
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    c[idx] = -q*(delta_x**2)/(2*(k*p))


# borde interior con generación 
def equation_borde_gen_da(i, j, q):
    # Ecuación para nodos en el borde
    idx = i + j * Nx
    A[idx, idx] = -4 # Coeficiente para el nodo actual
    A[idx, idx - Nx] = 1  # Coeficiente para el nodo abajo
    A[idx, idx - 1] = 1  # Coeficiente para el nodo a la izquierda
    A[idx, idx + Nx] = 1  # Coeficiente para el nodo arriba
    A[idx, idx + 1] = 1  # Coeficiente para el nodo a la derecha
    c[idx] = -q*(delta_x**2)/(2*(k*p))

# definición de limites de malla

# puntos de caja

# Llena la matriz A con las ecuaciones correspondientes para cada tipo de nodo
def termo_solver(q):
    for i in range(x_len):
        for j in range(y_len):
            if i >= 1 and i < 15 and j >= 1 and j < 15:
                equation_interior_gen(i, j, q)
            elif i == 30 and j == 30:
                equation_interior_wc(i, j, q)
            elif (i == 50 and j >= 1 and j < 30) or (i == 30 and j >= 31 and j < 50): ##
                equation_plane_wc_der(i, j, q)
            elif (j == 30 and i >= 31 and i < 50) or (j == 50 and i >= 1 and i < 30): ##
                equation_plane_wc_arr(i, j, q)
            elif (j == 0 and i >= 16 and i < 50):
                equation_plane_wc_aba(i, j, q)
            elif (i == 30 and j == 50) or (i == 50 and j == 30):
                equation_esquina_wc_case4(i, j, q)
            elif (i == 0 and j >= 16 and j < 50):
                equation_plane_wc_izq(i, j, q)
            elif (i == 0 and j == 50):
                equation_esquina_arr(i, j, q)
            elif (i == 50 and j == 0):
                equation_esquina_aba(i, j, q)
            elif (j == 0 and i >= 1 and i < 15):
                equation_borde_aba(i, j, q)
            elif (i == 0 and j >= 1 and j < 15):
                equation_borde_izq(i, j, q)
            elif (i == 0 and j == 0):
                equation_esquina_gen(i, j, q)
            elif (i == 0 and j == 15):
                equation_esquina_gen_ais_izq(i, j, q)
            elif (j == 0 and i == 15):
                equation_esquina_gen_ais_aba(i, j, q)
            elif (j == 15 and i == 15):
                equation_esquina_interior_gen(i, j, q)
            elif (i == 15 and j >= 1 and j < 15):
                equation_borde_gen(i, j, q)
            elif (j == 15 and i >= 1 and i < 15):
                equation_borde_gen_da(i, j, q)
            elif (i >= 16 and i < 50 and j >= 1 and j < 30):
                # Nodo interior
                equation_interior(i, j, q)
            elif (i >= 1 and i < 16 and j >= 16 and j < 30):
                # Nodo interior
                equation_interior(i, j, q)
            elif (i >= 1 and i < 30 and j >= 30 and j < 50):
                # Nodo interior
                equation_interior(i, j, q)
    # Resuelve el sistema de ecuaciones A * b = c

    filas_a_eliminar = []
    for i, fila in enumerate(A):
        if np.all(fila == 0):
            filas_a_eliminar.append(i)

    columnas_a_eliminar = []
    for j in range(A.shape[1]):
        if np.all(A[:, j] == 0):
            columnas_a_eliminar.append(j)

    A_n = np.delete(A, filas_a_eliminar, axis=0)
    A_n = np.delete(A_n, columnas_a_eliminar, axis=1)
    c_n = np.delete(c, filas_a_eliminar)

    # Actualiza la matriz de temperaturas T con los valores en b
    b = np.linalg.solve(A_n, c_n)
    # malla
    Lx = 0.5  # Longitud en el eje x
    La = 0.3
    Lb = 0.3
    # Ly = 0.5  # Longitud en el eje y
    # Crear una malla
    x_a = np.linspace(0, Lx, Nx)
    y_a = np.linspace(0, La, 31)

    x_b = np.linspace(0, Lb, 31)
    y_b = np.linspace(0.31, 0.5, 20)

    X_, Y_ = np.meshgrid(x_a, y_a)
    X2, Y2 = np.meshgrid(x_b, y_b)

    coordinates_a = np.vstack((X_.flatten(), Y_.flatten())).T
    coordinates_b = np.vstack((X2.flatten(), Y2.flatten())).T

    data = pd.DataFrame({
        'X': np.concatenate((coordinates_a[:,0],coordinates_b[:,0]))
    })

    data['Y'] = np.concatenate((coordinates_a[:,1],coordinates_b[:,1]))
    data['Temp'] = b


    # Visualización de la temperatura
    # X = data['X']
    # Y = data['Y']
    # T = data['Temp']
    return data

dq = 10 #w
goal = 720 #°C
iter = True
init = 6*10**3
while iter:
    x_valor_deseado = 0.3  
    y_valor_deseado = 0.2
    info = termo_solver(init)
    filtro = (info['X'] == x_valor_deseado) & (info['Y'] == y_valor_deseado)
    indice = info.index[filtro].tolist()
    esquina = info.loc[indice, 'Temp'].to_list()
    if esquina[0] <= goal:
        init += dq
    else:
        iter = False
    

# Crea una figura 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
my_cmap = plt.get_cmap('hot')
ax.scatter(info['X'], info['Y'], info['Temp'],cmap = my_cmap)
# Etiqueta los ejes
ax.set_xlabel('X (m)')
ax.set_ylabel('Y (m)')
ax.set_zlabel('Temperatura (°C)')
plt.title('Distribución de temperatura')
fig.savefig('Distribucion.png')
plt.show()
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_904\2375000089.py:339: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(info['X'], info['Y'], info['Temp'],cmap = my_cmap)

# %%
scatter = plt.scatter(info['X'], info['Y'], s=info['Temp'], cmap='viridis', c=info['Temp'], marker='o', alpha=0.5)
plt.colorbar(scatter, label='Temperatura (°C)')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title('Distribución de temperatura')
plt.savefig("curva1.png")

# %%
temperatura = info['Temp']
x_min, x_max = 0.30, 0.5  # Ejemplo de rango de coordenada X
y_min, y_max = 0.30, 0.5  # Ejemplo de rango de coordenada Y
rect = Rectangle((x_min, y_min), x_max - x_min, y_max - y_min, fill=True, color='white')
level = 50
tcf = plt.tricontourf(info['X'], info['Y'], temperatura,levels=level, linewidths=0.5, cmap='plasma')
plt.colorbar(tcf, label='Temperatura (°C)') 
contorno_lines = plt.tricontour(info['X'], info['Y'], temperatura,levels=level, colors='k', linewidths=1)
# plt.clabel(tcf, fmt='%2.1f', colors='w', fontsize=14)
plt.title('Modelo de tranferencia',
          fontsize=14, fontweight='bold')
# Agrega el cuadrado al gráfico
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.gca().add_patch(rect)
plt.savefig('grafica3.png')
plt.show()
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_904\2855954717.py:6: UserWarning: linewidths is ignored by contourf
#   tcf = plt.tricontourf(info['X'], info['Y'], temperatura,levels=level, linewidths=0.5, cmap='plasma')

# %%
temperatura = info['Temp']
# Define las coordenadas y tamaños de los dos cuadrados
cuadrado1 = Rectangle((0.25, 0.1), 0.05, 0.1, fill=False, color='white')
cuadrado2 = Rectangle((0.1, 0.25), 0.1, 0.05, fill=False, color='white')
x_min, x_max = 0.30, 0.5  # Ejemplo de rango de coordenada X
y_min, y_max = 0.30, 0.5  # Ejemplo de rango de coordenada Y
rect = Rectangle((x_min, y_min), x_max - x_min, y_max - y_min, fill=True, color='white')
level = 50
tcf = plt.tricontourf(info['X'], info['Y'], temperatura, levels=level, linewidths=0.5, cmap='plasma')
plt.colorbar(tcf, label='Temperatura (°C)')
contorno_lines = plt.tricontour(info['X'], info['Y'], temperatura, levels=level, colors='k', linewidths=1)
# Agrega los cuadrados al gráfico
plt.gca().add_patch(cuadrado1)
plt.gca().add_patch(cuadrado2)
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title('Modelo de transferencia', fontsize=14, fontweight='bold')
plt.gca().add_patch(rect)
plt.savefig('grafica4.png')
plt.show()
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_904\1236396689.py:9: UserWarning: linewidths is ignored by contourf
#   tcf = plt.tricontourf(info['X'], info['Y'], temperatura, levels=level, linewidths=0.5, cmap='plasma')

# %%
# Convierte coordenadas x e y a coordenadas polares
r = np.sqrt(info['X']**2 + info['Y']**2)
theta = np.arctan2(info['Y'], info['X'])
# Duplica tus datos para reflejar los cuatro cuadrantes
r_reflejado = np.concatenate((r, r, r, r))
theta_reflejado = np.concatenate((theta, -theta, np.pi - theta, -np.pi + theta))
temp_reflejado = np.tile(info['Temp'], 4)
x_min, x_max = 0.30, 0.5  # Ejemplo de rango de coordenada X
y_min, y_max = 0.30, 0.5  # Ejemplo de rango de coordenada Y
rect = Rectangle((x_min, y_min), x_max - x_min, y_max - y_min, fill=True, color='white')
# Crea un gráfico de contorno polar para los cuatro cuadrantes reflejados
fig = plt.figure(figsize=(6, 6))
lv = 50
ax = fig.add_subplot(111, projection='polar')
contorno = ax.tricontourf(theta_reflejado, r_reflejado, temp_reflejado,levels=lv,
                           cmap='hot')
plt.title('Distribucion te T Horno Completo')
# Agrega una barra de colores
plt.colorbar(contorno, ax=ax, label='Temperatura (°C)')
# Muestra el gráfico
plt.savefig('horno.png')
plt.show()

# %%
Temp = esquina
calor = init
print(f"La temperatura más alejada de los cuadros a la fuente esta en {Temp} °C, con un calor de fuente de {calor} W")
# Out:
# La temperatura más alejada de los cuadros a la fuente esta en [720.7107086971364] °C, con un calor de fuente de 6360 W
